# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df=sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x=df.drop('species',axis=1)
y=df['species']

# %%
x_train,x_test,y_train,y_test=train_test_split(x ,y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn=KNeighborsClassifier()

# %%
model_knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
model_knn.score(x_test,y_test)#over fit
# Out:
# 0.98

# %%
from sklearn.svm import SVC
model_svm=SVC(gamma='auto')

# %%
model_svm.fit(x_train,y_train)
model_svm.score(x_test,y_test)#over fit
# Out:
# 1.0

# %% [markdown]
# SO NOW USE THE GRID SEARCH CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
#with cv
classifier=GridSearchCV((model_svm),{
    'C':[1,10,20,30],'kernel':['rbf','linear']
},cv=5,return_train_score=False)

# %%
#we dont need  train test split in cv
classifier.fit(x,y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30], 'kernel': ['rbf', 'linear']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.00395808, 0.00338416, 0.0029254 , 0.00204749, 0.00156002,
#         0.00144887, 0.00153275, 0.00207028]),
#  'std_fit_time': array([0.00109045, 0.00118158, 0.00105973, 0.00061496, 0.00015305,
#         0.00017497, 0.00023875, 0.00059439]),
#  'mean_score_time': array([0.00318303, 0.00335393, 0.00217371, 0.00141902, 0.00120931,
#         0.00106907, 0.00129571, 0.00128903]),
#  'std_score_time': array([0.00169977, 0.00205675, 0.00089656, 0.00048532, 0.00011073,
#         0.0001701 , 0.0003129 , 0.00024283]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 30, 30],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear',
#                     'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
# ...

# %%
results=pd.DataFrame(classifier.cv_results_)

# %%
results.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.003958      0.001090         0.003183        0.001700        1
# 1       0.003384      0.001182         0.003354        0.002057        1
# 2       0.002925      0.001060         0.002174        0.000897       10
# 3       0.002047      0.000615         0.001419        0.000485       10
# 4       0.001560      0.000153         0.001209        0.000111       20
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 1       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# 3       linear  {'C': 10, 'kernel': 'linear'}           1.000000
# 4          rbf     {'C': 20, 'kernel': 'rbf'}           0.966667
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# ...

# %%
results[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.980000
# 1        1       linear         0.980000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667
# 6       30          rbf         0.960000
# 7       30       linear         0.960000

# %% [markdown]
# GRID SEARCH CV WITH KNN

# %%
classifier2= GridSearchCV((model_knn),{
    'n_neighbors':[3,5,7,9,11],'weights':['uniform','distance'],'metric':['minkowski','manhattan','euclidean']
},cv=5,return_train_score=False,error_score='raise')

# %%
classifier2.fit(x,y)
# Out:
# GridSearchCV(cv=5, error_score='raise', estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['minkowski', 'manhattan', 'euclidean'],
#                          'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform', 'distance']})

# %%
results2=pd.DataFrame(classifier2.cv_results_)

# %%
results2
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_metric  \
# 0        0.002232      0.000544         0.004205        0.000390    minkowski
# 1        0.002201      0.000253         0.002853        0.000720    minkowski
# 2        0.001613      0.000272         0.003166        0.000577    minkowski
# 3        0.001375      0.000171         0.001571        0.000148    minkowski
# 4        0.001939      0.000556         0.003802        0.000436    minkowski
# 5        0.001523      0.000197         0.002070        0.000379    minkowski
# 6        0.001665      0.000138         0.003455        0.000423    minkowski
# 7        0.001565      0.000145         0.001820        0.000284    minkowski
# 8        0.001614      0.000143         0.003588        0.000490    minkowski
# 9        0.001437      0.000223         0.001718        0.000107    minkowski
# 10       0.001828      0.000344         0.003598        0.000502    manhattan
# ...
